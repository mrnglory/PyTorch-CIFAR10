# %%
import torch
import torch.nn as nn
import math
from torch.optim import Optimizer
from torch.utils.data import DataLoader
import torchvision
from torchvision import datasets
from torchvision.transforms import transforms

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

'''
Step 1:
'''

# Image preprocessing modules
transform = transforms.Compose([
    transforms.Pad(4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32),
    transforms.ToTensor()])

train_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                 train=True, 
                                 transform=transform,
                                 download=True)

test_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                train=False, 
                                transform=transforms.ToTensor())
    
'''
Step 2
'''

class VGG13(nn.Module) :
    def __init__(self) :
        super(VGG13, self).__init__()
        
        self.conv_layer1 = nn.Sequential(
                nn.Conv2d(3, 64, kernel_size=3, padding=1),     # 64 * 32 * 32
                nn.ReLU(),
                nn.Conv2d(64, 64, kernel_size=3, padding=1),    # 64 * 32 * 32
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)           # 64 * 16 * 16
                )
        self.conv_layer2 = nn.Sequential(
                nn.Conv2d(64, 128, kernel_size=3, padding=1),   # 128 * 16 * 16
                nn.ReLU(),
                nn.Conv2d(128, 128, kernel_size=3, padding=1),  # 128 * 16 * 16
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)           # 128 * 8 * 8
                )
        self.conv_layer3 = nn.Sequential(
                nn.Conv2d(128, 256, kernel_size=3, padding=1),  # 256 * 8 * 8
                nn.ReLU(),
                nn.Conv2d(256, 256, kernel_size=3, padding=1),  # 256 * 8 * 8
                nn.ReLU(),
                nn.Conv2d(256, 256, kernel_size=3, padding=1),  # 256 * 8 * 8
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)           # 256 * 4 * 4
                )
        self.conv_layer4 = nn.Sequential(
                nn.Conv2d(256, 512, kernel_size=3, padding=1),  # 512 * 4 * 4
                nn.ReLU(),
                nn.Conv2d(512, 512, kernel_size=3, padding=1),  # 512 * 4 * 4
                nn.ReLU(),
                nn.Conv2d(512, 512, kernel_size=3, padding=1),  # 512 * 4 * 4
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2),          # 512 * 2 * 2
                )
        self.fc_layer1 = nn.Sequential(
                nn.Dropout(),
                nn.Linear(512*2*2, 4096),                           # 1 * 4096
                nn.ReLU()
                )
        self.fc_layer2 = nn.Sequential(
                nn.Dropout(),
                nn.Linear(4096, 4096),                          # 1 * 4096
                nn.ReLU()
                )
        self.fc_layer3 = nn.Sequential(
                nn.Linear(4096, 10),                     # 1 * num_class
                )

        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                m.bias.data.zero_()
        
    def forward(self, x) :
        output = self.conv_layer1(x)
        output = self.conv_layer2(output)
        output = self.conv_layer3(output)
        output = self.conv_layer4(output)
        output = output.view(-1, 512*2*2)
        output = self.fc_layer1(output)
        output = self.fc_layer2(output)
        output = self.fc_layer3(output)
        return output


'''
Step 3
'''
model = VGG13().to(device)
loss_function = torch.nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr=0.005, momentum=0.9, weight_decay=5e-4)

'''
Step 4
'''
# train_loss_list = []

model.train()
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=100, shuffle=True)

import time
start = time.time()
for epoch in range(200) :
    print("{}th epoch starting.".format(epoch))
    for i, (images, labels) in enumerate(train_loader) :
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        train_loss = loss_function(model(images), labels)
        train_loss.backward()        
        
        optimizer.step()
        

    print ("Epoch [{}] Loss: {:.4f}".format(epoch+1, train_loss.item()))

end = time.time()
print("Time ellapsed in training is: {}".format(end - start))


'''
Step 5
'''

model.eval()
test_loss, correct, total = 0, 0, 0

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=100, shuffle=False)
with torch.no_grad():
    for images, labels in test_loader :
        images, labels = images.to(device), labels.to(device)

        output = model(images)
        test_loss += loss_function(output, labels).item()

        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()
        
        # train_acc_list.append(correct)

        total += labels.size(0)

print('[Test set] Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss /total, correct, total,
        100. * correct / total))


'''
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def imshow(img):
    img = img/2 + 0.5
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()
    
dataiter = iter(test_loader)
images, labels = dataiter.next()
imshow(torchvision.utils.make_grid(images))

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
'''
'''
plt.plot([i for i in range(1, epoch+1)], train_loss_list, label = 'training loss')
plt.plot([i for i in range(1, epoch+1)], train_acc_list, label = 'training accuracy')
plt.legend()
plt.title('VGG13, Accuracy and Loss across Epochs')
'''
# Out:
# Files already downloaded and verified
# 0th epoch starting.
# Epoch [1] Loss: 2.0590
# 1th epoch starting.
# Epoch [2] Loss: 1.7525
# 2th epoch starting.
# Epoch [3] Loss: 1.5972
# 3th epoch starting.
# Epoch [4] Loss: 1.4964
# 4th epoch starting.
# Epoch [5] Loss: 1.3415
# 5th epoch starting.
# Epoch [6] Loss: 1.2043
# 6th epoch starting.
# Epoch [7] Loss: 1.1677
# 7th epoch starting.
# Epoch [8] Loss: 1.0681
# 8th epoch starting.
# Epoch [9] Loss: 0.8411
# 9th epoch starting.
# Epoch [10] Loss: 0.8721
# 10th epoch starting.
# Epoch [11] Loss: 0.5897
# 11th epoch starting.
# Epoch [12] Loss: 0.7262
# 12th epoch starting.
# Epoch [13] Loss: 0.6207
# 13th epoch starting.
# Epoch [14] Loss: 0.6055
# 14th epoch starting.
# Epoch [15] Loss: 0.5111
# 15th epoch starting.
# Epoch [16] Loss: 0.4868
# 16th epoch starting.
# Epoch [17] Loss: 0.5486
# 17th epoch starting.
# Epoch [18] Loss: 0.5503
# 18th epoch starting.
# Epoch [19] Loss: 0.5102
# 19th epoch starting.
# Epoch [20] Loss: 0.3855
# 20th epoch starting.
# Epoch [21] Loss: 0.4974
# 21th epoch starting.
# Epoch [22] Loss: 0.3579
# 22th epoch starting.
# Epoch [23] Loss: 0.4470
# 23th epoch starting.
# Epoch [24] Loss: 0.4736
# 24th epoch starting.
# Epoch [25] Loss: 0.4316
# 25th epoch starting.
# Epoch [26] Loss: 0.4031
# 26th epoch starting.
# Epoch [27] Loss: 0.3482
# 27th epoch starting.
# Epoch [28] Loss: 0.1830
# 28th epoch starting.
# Epoch [29] Loss: 0.3883
# 29th epoch starting.
# Epoch [30] Loss: 0.4087
# 30th epoch starting.
# Epoch [31] Loss: 0.3114
# 31th epoch starting.
# Epoch [32] Loss: 0.1811
# 32th epoch starting.
# Epoch [33] Loss: 0.2673
# 33th epoch starting.
# Epoch [34] Loss: 0.1572
# 34th epoch starting.
# Epoch [35] Loss: 0.2569
# 35th epoch starting.
# Epoch [36] Loss: 0.0959
# 36th epoch starting.
# Epoch [37] Loss: 0.1707
# 37th epoch starting.
# Epoch [38] Loss: 0.1881
# 38th epoch starting.
# Epoch [39] Loss: 0.2174
# 39th epoch starting.
# Epoch [40] Loss: 0.0798
# 40th epoch starting.
# Epoch [41] Loss: 0.1267
# 41th epoch starting.
# Epoch [42] Loss: 0.2461
# 42th epoch starting.
# Epoch [43] Loss: 0.1859
# 43th epoch starting.
# Epoch [44] Loss: 0.1480
# 44th epoch starting.
# Epoch [45] Loss: 0.1583
# 45th epoch starting.
# Epoch [46] Loss: 0.1242
# 46th epoch starting.
# Epoch [47] Loss: 0.1324
# 47th epoch starting.
# Epoch [48] Loss: 0.1642
# 48th epoch starting.
# Epoch [49] Loss: 0.1042
# 49th epoch starting.
# Epoch [50] Loss: 0.1796
# 50th epoch starting.
# Epoch [51] Loss: 0.1046
# 51th epoch starting.
# Epoch [52] Loss: 0.1811
# 52th epoch starting.
# Epoch [53] Loss: 0.1517
# 53th epoch starting.
# Epoch [54] Loss: 0.1003
# 54th epoch starting.
# Epoch [55] Loss: 0.1276
# 55th epoch starting.
# Epoch [56] Loss: 0.1363
# 56th epoch starting.
# Epoch [57] Loss: 0.1252
# 57th epoch starting.
# Epoch [58] Loss: 0.0831
# 58th epoch starting.
# Epoch [59] Loss: 0.0769
# 59th epoch starting.
# Epoch [60] Loss: 0.0368
# 60th epoch starting.
# Epoch [61] Loss: 0.0632
# 61th epoch starting.
# Epoch [62] Loss: 0.0878
# 62th epoch starting.
# Epoch [63] Loss: 0.0948
# 63th epoch starting.
# Epoch [64] Loss: 0.0602
# 64th epoch starting.
# Epoch [65] Loss: 0.1051
# 65th epoch starting.
# Epoch [66] Loss: 0.0520
# 66th epoch starting.
# Epoch [67] Loss: 0.1134
# 67th epoch starting.
# Epoch [68] Loss: 0.0586
# 68th epoch starting.
# Epoch [69] Loss: 0.1539
# 69th epoch starting.
# Epoch [70] Loss: 0.1527
# 70th epoch starting.
# Epoch [71] Loss: 0.1312
# 71th epoch starting.
# Epoch [72] Loss: 0.0372
# 72th epoch starting.
# Epoch [73] Loss: 0.1187
# 73th epoch starting.
# Epoch [74] Loss: 0.1017
# 74th epoch starting.
# Epoch [75] Loss: 0.0434
# 75th epoch starting.
# Epoch [76] Loss: 0.0582
# 76th epoch starting.
# Epoch [77] Loss: 0.1133
# 77th epoch starting.
# Epoch [78] Loss: 0.0481
# 78th epoch starting.
# Epoch [79] Loss: 0.0512
# 79th epoch starting.
# Epoch [80] Loss: 0.2039
# 80th epoch starting.
# Epoch [81] Loss: 0.0864
# 81th epoch starting.
# Epoch [82] Loss: 0.0922
# 82th epoch starting.
# Epoch [83] Loss: 0.0880
# 83th epoch starting.
# Epoch [84] Loss: 0.1190
# 84th epoch starting.
# Epoch [85] Loss: 0.0964
# 85th epoch starting.
# Epoch [86] Loss: 0.0769
# 86th epoch starting.
# Epoch [87] Loss: 0.0908
# 87th epoch starting.
# Epoch [88] Loss: 0.0802
# 88th epoch starting.
# Epoch [89] Loss: 0.0479
# 89th epoch starting.
# Epoch [90] Loss: 0.1340
# 90th epoch starting.
# Epoch [91] Loss: 0.0390
# 91th epoch starting.
# Epoch [92] Loss: 0.1233
# 92th epoch starting.
# Epoch [93] Loss: 0.1591
# 93th epoch starting.
# Epoch [94] Loss: 0.1127
# 94th epoch starting.
# Epoch [95] Loss: 0.0309
# 95th epoch starting.
# Epoch [96] Loss: 0.0803
# 96th epoch starting.
# Epoch [97] Loss: 0.0751
# 97th epoch starting.
# Epoch [98] Loss: 0.0799
# 98th epoch starting.
# Epoch [99] Loss: 0.0367
# 99th epoch starting.
# Epoch [100] Loss: 0.0634
# 100th epoch starting.
# Epoch [101] Loss: 0.0849
# 101th epoch starting.
# Epoch [102] Loss: 0.0156
# 102th epoch starting.
# Epoch [103] Loss: 0.0593
# 103th epoch starting.
# Epoch [104] Loss: 0.0674
# 104th epoch starting.
# Epoch [105] Loss: 0.0457
# 105th epoch starting.
# Epoch [106] Loss: 0.0236
# 106th epoch starting.
# Epoch [107] Loss: 0.0176
# 107th epoch starting.
# Epoch [108] Loss: 0.0427
# 108th epoch starting.
# Epoch [109] Loss: 0.0716
# 109th epoch starting.
# Epoch [110] Loss: 0.0190
# 110th epoch starting.
# Epoch [111] Loss: 0.1674
# 111th epoch starting.
# Epoch [112] Loss: 0.0537
# 112th epoch starting.
# Epoch [113] Loss: 0.0582
# 113th epoch starting.
# Epoch [114] Loss: 0.0580
# 114th epoch starting.
# Epoch [115] Loss: 0.0468
# 115th epoch starting.
# Epoch [116] Loss: 0.0277
# 116th epoch starting.
# Epoch [117] Loss: 0.0993
# 117th epoch starting.
# Epoch [118] Loss: 0.0286
# 118th epoch starting.
# Epoch [119] Loss: 0.0424
# 119th epoch starting.
# Epoch [120] Loss: 0.1019
# 120th epoch starting.
# Epoch [121] Loss: 0.0297
# 121th epoch starting.
# Epoch [122] Loss: 0.1046
# 122th epoch starting.
# Epoch [123] Loss: 0.1279
# 123th epoch starting.
# Epoch [124] Loss: 0.0299
# 124th epoch starting.
# Epoch [125] Loss: 0.0153
# 125th epoch starting.
# Epoch [126] Loss: 0.0654
# 126th epoch starting.
# Epoch [127] Loss: 0.0304
# 127th epoch starting.
# Epoch [128] Loss: 0.0373
# 128th epoch starting.
# Epoch [129] Loss: 0.0418
# 129th epoch starting.
# Epoch [130] Loss: 0.0469
# 130th epoch starting.
# Epoch [131] Loss: 0.0823
# 131th epoch starting.
# Epoch [132] Loss: 0.0342
# 132th epoch starting.
# Epoch [133] Loss: 0.0621
# 133th epoch starting.
# Epoch [134] Loss: 0.0975
# 134th epoch starting.
# Epoch [135] Loss: 0.0591
# 135th epoch starting.
# Epoch [136] Loss: 0.0448
# 136th epoch starting.
# Epoch [137] Loss: 0.0121
# 137th epoch starting.
# Epoch [138] Loss: 0.0972
# 138th epoch starting.
# Epoch [139] Loss: 0.0495
# 139th epoch starting.
# Epoch [140] Loss: 0.0548
# 140th epoch starting.
# Epoch [141] Loss: 0.1242
# 141th epoch starting.
# Epoch [142] Loss: 0.0167
# 142th epoch starting.
# Epoch [143] Loss: 0.0669
# 143th epoch starting.
# Epoch [144] Loss: 0.0662
# 144th epoch starting.
# Epoch [145] Loss: 0.0097
# 145th epoch starting.
# Epoch [146] Loss: 0.0220
# 146th epoch starting.
# Epoch [147] Loss: 0.0142
# 147th epoch starting.
# Epoch [148] Loss: 0.0222
# 148th epoch starting.
# Epoch [149] Loss: 0.1181
# 149th epoch starting.
# Epoch [150] Loss: 0.0119
# 150th epoch starting.
# Epoch [151] Loss: 0.0309
# 151th epoch starting.
# Epoch [152] Loss: 0.0367
# 152th epoch starting.
# Epoch [153] Loss: 0.0392
# 153th epoch starting.
# Epoch [154] Loss: 0.0770
# 154th epoch starting.
# Epoch [155] Loss: 0.0301
# 155th epoch starting.
# Epoch [156] Loss: 0.0386
# 156th epoch starting.
# Epoch [157] Loss: 0.0606
# 157th epoch starting.
# Epoch [158] Loss: 0.0361
# 158th epoch starting.
# Epoch [159] Loss: 0.1403
# 159th epoch starting.
# Epoch [160] Loss: 0.0198
# 160th epoch starting.
# Epoch [161] Loss: 0.0401
# 161th epoch starting.
# Epoch [162] Loss: 0.0438
# 162th epoch starting.
# Epoch [163] Loss: 0.0538
# 163th epoch starting.
# Epoch [164] Loss: 0.0652
# 164th epoch starting.
# Epoch [165] Loss: 0.0268
# 165th epoch starting.
# Epoch [166] Loss: 0.0591
# 166th epoch starting.
# Epoch [167] Loss: 0.1042
# 167th epoch starting.
# Epoch [168] Loss: 0.0501
# 168th epoch starting.
# Epoch [169] Loss: 0.0295
# 169th epoch starting.
# Epoch [170] Loss: 0.0376
# 170th epoch starting.
# Epoch [171] Loss: 0.0120
# 171th epoch starting.
# Epoch [172] Loss: 0.0593
# 172th epoch starting.
# Epoch [173] Loss: 0.0694
# 173th epoch starting.
# Epoch [174] Loss: 0.0411
# 174th epoch starting.
# Epoch [175] Loss: 0.0685
# 175th epoch starting.
# Epoch [176] Loss: 0.0362
# 176th epoch starting.
# Epoch [177] Loss: 0.0793
# 177th epoch starting.
# Epoch [178] Loss: 0.0480
# 178th epoch starting.
# Epoch [179] Loss: 0.0469
# 179th epoch starting.
# Epoch [180] Loss: 0.0732
# 180th epoch starting.
# Epoch [181] Loss: 0.0252
# 181th epoch starting.
# Epoch [182] Loss: 0.0409
# 182th epoch starting.
# Epoch [183] Loss: 0.0305
# 183th epoch starting.
# Epoch [184] Loss: 0.0766
# 184th epoch starting.
# Epoch [185] Loss: 0.1490
# 185th epoch starting.
# Epoch [186] Loss: 0.0056
# 186th epoch starting.
# Epoch [187] Loss: 0.0425
# 187th epoch starting.
# Epoch [188] Loss: 0.0571
# 188th epoch starting.
# Epoch [189] Loss: 0.0596
# 189th epoch starting.
# Epoch [190] Loss: 0.0652
# 190th epoch starting.
# Epoch [191] Loss: 0.1625
# 191th epoch starting.
# Epoch [192] Loss: 0.0418
# 192th epoch starting.
# Epoch [193] Loss: 0.0353
# 193th epoch starting.
# Epoch [194] Loss: 0.0359
# 194th epoch starting.
# Epoch [195] Loss: 0.1066
# 195th epoch starting.
# Epoch [196] Loss: 0.0809
# 196th epoch starting.
# Epoch [197] Loss: 0.0579
# 197th epoch starting.
# Epoch [198] Loss: 0.0290
# 198th epoch starting.
# Epoch [199] Loss: 0.0442
# 199th epoch starting.
# Epoch [200] Loss: 0.0239
# 200th epoch starting.
# Epoch [201] Loss: 0.0324
# 201th epoch starting.
# Epoch [202] Loss: 0.0378
# 202th epoch starting.
# Epoch [203] Loss: 0.0074
# 203th epoch starting.
# Epoch [204] Loss: 0.0311
# 204th epoch starting.
# Epoch [205] Loss: 0.0193
# 205th epoch starting.
# Epoch [206] Loss: 0.1627
# 206th epoch starting.
# Epoch [207] Loss: 0.0200
# 207th epoch starting.
# Epoch [208] Loss: 0.0489
# 208th epoch starting.
# Epoch [209] Loss: 0.0176
# 209th epoch starting.
# Epoch [210] Loss: 0.0472
# 210th epoch starting.
# Epoch [211] Loss: 0.0115
# 211th epoch starting.
# Epoch [212] Loss: 0.0654
# 212th epoch starting.
# Epoch [213] Loss: 0.0146
# 213th epoch starting.
# Epoch [214] Loss: 0.0315
# 214th epoch starting.
# Epoch [215] Loss: 0.0314
# 215th epoch starting.
# Epoch [216] Loss: 0.0227
# 216th epoch starting.
# Epoch [217] Loss: 0.0098
# 217th epoch starting.
# Epoch [218] Loss: 0.0408
# 218th epoch starting.
# Epoch [219] Loss: 0.0518
# 219th epoch starting.
# Epoch [220] Loss: 0.0547
# 220th epoch starting.
# Epoch [221] Loss: 0.0820
# 221th epoch starting.
# Epoch [222] Loss: 0.0547
# 222th epoch starting.
# Epoch [223] Loss: 0.0058
# 223th epoch starting.
# Epoch [224] Loss: 0.0158
# 224th epoch starting.
# Epoch [225] Loss: 0.0969
# 225th epoch starting.
# Epoch [226] Loss: 0.0644
# 226th epoch starting.
# Epoch [227] Loss: 0.0326
# 227th epoch starting.
# Epoch [228] Loss: 0.0316
# 228th epoch starting.
# Epoch [229] Loss: 0.0267
# 229th epoch starting.
# Epoch [230] Loss: 0.0210
# 230th epoch starting.
# Epoch [231] Loss: 0.0801
# 231th epoch starting.
# Epoch [232] Loss: 0.0390
# 232th epoch starting.
# Epoch [233] Loss: 0.0248
# 233th epoch starting.
# Epoch [234] Loss: 0.0226
# 234th epoch starting.
# Epoch [235] Loss: 0.0311
# 235th epoch starting.
# Epoch [236] Loss: 0.0353
# 236th epoch starting.
# Epoch [237] Loss: 0.0178
# 237th epoch starting.
# Epoch [238] Loss: 0.0493
# 238th epoch starting.
# Epoch [239] Loss: 0.0340
# 239th epoch starting.
# Epoch [240] Loss: 0.0254
# 240th epoch starting.
# Epoch [241] Loss: 0.0318
# 241th epoch starting.
# Epoch [242] Loss: 0.0325
# 242th epoch starting.
# Epoch [243] Loss: 0.0477
# 243th epoch starting.
# Epoch [244] Loss: 0.0381
# 244th epoch starting.
# Epoch [245] Loss: 0.0105
# 245th epoch starting.
# Epoch [246] Loss: 0.0534
# 246th epoch starting.
# Epoch [247] Loss: 0.0158
# 247th epoch starting.
# Epoch [248] Loss: 0.0116
# 248th epoch starting.
# Epoch [249] Loss: 0.0310
# 249th epoch starting.
# Epoch [250] Loss: 0.0261
# Time ellapsed in training is: 17665.227663517
# [Test set] Average loss: 0.0048, Accuracy: 8889/10000 (88.89%)
# "\nplt.plot([i for i in range(1, epoch+1)], train_loss_list, label = 'training loss')\nplt.plot([i for i in range(1, epoch+1)], train_acc_list, label = 'training accuracy')\nplt.legend()\nplt.title('VGG13, Accuracy and Loss across Epochs')\n"
